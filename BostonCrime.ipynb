# %% [markdown]
# ### Big Data Architecture and Data Governance

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\ygrov\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\ygrov\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (2.0.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ygrov\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ygrov\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ygrov\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\ygrov\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\ygrov\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\ygrov\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scipy) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\ygrov\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# importing libraries
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
# importing the dataset
df=pd.read_csv("crime.csv", decimal = ',' , encoding = "ISO-8859-1")

# %% [markdown]
# ### Exploring the dataset
#
# In below lines of code, we are just trying to check the dataset description, datatypes, sample size etc.

# %%
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0      I182078893           413  Aggravated Assault
# 1      I182078893          2662          Ballistics
# 2      I182078872           413  Aggravated Assault
# 3      I182077958           413  Aggravated Assault
# 4      I182077958          2662          Ballistics
#
#               OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0  ASSAULT - AGGRAVATED - BATTERY      C11            416        Y
# 1       BALLISTICS EVIDENCE/FOUND      C11            416        Y
# 2  ASSAULT - AGGRAVATED - BATTERY       B2            330        Y
# 3  ASSAULT - AGGRAVATED - BATTERY       B3            428        Y
# 4       BALLISTICS EVIDENCE/FOUND       B3            428        Y
#
#   OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  UCR_PART         STREET  \
# 0  9/29/2018 21:12  2018      9    Saturday    21  Part One  WASHINGTON ST
# 1  9/29/2018 21:12  2018      9    Saturday    21  Part Two  WASHINGTON ST
# 2  9/29/2018 19:21  2018      9    Saturday    19  Part One      SEAVER ST
# 3  9/26/2018 20:20  2018      9   Wednesday    20  Part One      MORTON ST
# 4  9/26/2018 20:20  2018      9   Wednesday    20  Part Two      MORTON ST
#
#            Lat          Long                     Location
# 0  42.28164735  -71.07111848  (42.28164735, -71.07111848)
# 1  42.28164735  -71.07111848  (42.28164735, -71.07111848)
# 2  42.30455372  -71.08295366  (42.30455372, -71.08295366)
# 3  42.28374593  -71.08938232  (42.28374593, -71.08938232)
# 4  42.28374593  -71.08938232  (42.28374593, -71.08938232)

# %%
df.info
# Out:
# <bound method DataFrame.info of        INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0           I182078893           413  Aggravated Assault
# 1           I182078893          2662          Ballistics
# 2           I182078872           413  Aggravated Assault
# 3           I182077958           413  Aggravated Assault
# 4           I182077958          2662          Ballistics
# ...                ...           ...                 ...
# 110786   I050310906-00          3125     Warrant Arrests
# 110787   I030217815-08           111            Homicide
# 110788   I030217815-08          3125     Warrant Arrests
# 110789   I010370257-00          3125     Warrant Arrests
# 110790       142052550          3125     Warrant Arrests
#
#                         OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0            ASSAULT - AGGRAVATED - BATTERY      C11            416        Y
# 1                 BALLISTICS EVIDENCE/FOUND      C11            416        Y
# 2            ASSAULT - AGGRAVATED - BATTERY       B2            330        Y
# 3            ASSAULT - AGGRAVATED - BATTERY       B3            428        Y
# 4                 BALLISTICS EVIDENCE/FOUND       B3            428        Y
# ...                                     ...      ...            ...      ...
# 110786                       WARRANT ARREST       D4            285        N
# 110787  MURDER, NON-NEGLIGIENT MANSLAUGHTER      E18            520        N
# 110788                       WARRANT ARREST      E18            520        N
# 110789                       WARRANT ARREST      E13            569        N
# 110790                       WARRANT ARREST       D4            903        N
#
#        OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 0       9/29/2018 21:12  2018      9    Saturday    21    Part One
# 1       9/29/2018 21:12  2018      9    Saturday    21    Part Two
# 2       9/29/2018 19:21  2018      9    Saturday    19    Part One
# 3       9/26/2018 20:20  2018      9   Wednesday    20    Part One
# 4       9/26/2018 20:20  2018      9   Wednesday    20    Part Two
# ...                 ...   ...    ...         ...   ...         ...
# 110786   6/5/2016 17:25  2016      6      Sunday    17  Part Three
# 110787   7/9/2015 13:38  2015      7    Thursday    13    Part One
# 110788   7/9/2015 13:38  2015      7    Thursday    13  Part Three
# 110789  5/31/2016 19:35  2016      5     Tuesday    19  Part Three
# 110790   6/22/2015 0:12  2015      6      Monday     0  Part Three
#
#                    STREET          Lat          Long  \
# 0           WASHINGTON ST  42.28164735  -71.07111848
# 1           WASHINGTON ST  42.28164735  -71.07111848
# 2               SEAVER ST  42.30455372  -71.08295366
# 3               MORTON ST  42.28374593  -71.08938232
# 4               MORTON ST  42.28374593  -71.08938232
# ...                   ...          ...           ...
# 110786        COVENTRY ST  42.33695098  -71.08574813
# 110787           RIVER ST  42.25592648  -71.12317207
# 110788           RIVER ST  42.25592648  -71.12317207
# 110789  NEW WASHINGTON ST  42.30233307  -71.11156487
# 110790      WASHINGTON ST  42.33383935  -71.08029038
#
#                            Location
# 0       (42.28164735, -71.07111848)
# 1       (42.28164735, -71.07111848)
# 2       (42.30455372, -71.08295366)
# 3       (42.28374593, -71.08938232)
# 4       (42.28374593, -71.08938232)
# ...                             ...
# 110786  (42.33695098, -71.08574813)
# 110787  (42.25592648, -71.12317207)
# 110788  (42.25592648, -71.12317207)
# 110789  (42.30233307, -71.11156487)
# 110790  (42.33383935, -71.08029038)
#
# [110791 rows x 17 columns]>

# %%
df.dtypes
# Out:
# INCIDENT_NUMBER        object
# OFFENSE_CODE            int64
# OFFENSE_CODE_GROUP     object
# OFFENSE_DESCRIPTION    object
# DISTRICT               object
# REPORTING_AREA         object
# SHOOTING               object
# OCCURRED_ON_DATE       object
# YEAR                    int64
# MONTH                   int64
# DAY_OF_WEEK            object
# HOUR                    int64
# UCR_PART               object
# STREET                 object
# Lat                    object
# Long                   object
# Location               object
# dtype: object

# %%
df.describe()
# Out:
#         OFFENSE_CODE           YEAR          MONTH           HOUR
# count  110791.000000  110791.000000  110791.000000  110791.000000
# mean     2302.123855    2016.343349       6.209936      13.044056
# std      1182.281667       0.559187       3.165624       6.307814
# min       111.000000    2015.000000       1.000000       0.000000
# 25%      1001.000000    2016.000000       4.000000       9.000000
# 50%      2914.000000    2016.000000       6.000000      14.000000
# 75%      3201.000000    2017.000000       9.000000      18.000000
# max      3831.000000    2018.000000      12.000000      23.000000

# %% [markdown]
# ### Data Cleaning
#
# We will be cleaning the dataset to get estimate of actual data and change any column data type in correct formats.
#
# Following action will be performed:
# 1. Changing date column in proper format.
# 2. We will also be checking the null values
# 3. Percentage of null values in the data
# 4. Change object type into string format.
# 5. Replace missing values with 'N' under shooting column and all NaN will be replaced by ' '

# %%
df["OCCURRED_ON_DATE"] = pd.to_datetime(df["OCCURRED_ON_DATE"], format="%m/%d/%Y %H:%M")

# %%
df.isnull().values.any()
# Out:
# np.False_

# %%
df.isnull().sum()
# Out:
# INCIDENT_NUMBER        0
# OFFENSE_CODE           0
# OFFENSE_CODE_GROUP     0
# OFFENSE_DESCRIPTION    0
# DISTRICT               0
# REPORTING_AREA         0
# SHOOTING               0
# OCCURRED_ON_DATE       0
# YEAR                   0
# MONTH                  0
# DAY_OF_WEEK            0
# HOUR                   0
# UCR_PART               0
# STREET                 0
# Lat                    0
# Long                   0
# Location               0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.groupby('OFFENSE_CODE_GROUP').count()
# Out:
#                                   INCIDENT_NUMBER  OFFENSE_CODE  \
# OFFENSE_CODE_GROUP
# Aggravated Assault                           2947          2947
# Aircraft                                        9             9
# Arson                                          40            40
# Assembly or Gathering Violations              343           343
# Auto Theft                                   1661          1661
# ...                                           ...           ...
# Towed                                        4177          4177
# Vandalism                                    5837          5837
# Verbal Disputes                              5003          5003
# Violations                                   1712          1712
# Warrant Arrests                              3365          3365
#
#                                   OFFENSE_DESCRIPTION  DISTRICT  \
# OFFENSE_CODE_GROUP
# Aggravated Assault                               2947      2947
# Aircraft                                            9         9
# Arson                                              40        40
# Assembly or Gathering Violations                  343       343
# Auto Theft                                       1661      1661
# ...                                               ...       ...
# Towed                                            4177      4177
# Vandalism                                        5837      5837
# Verbal Disputes                                  5003      5003
# Violations                                       1712      1712
# Warrant Arrests                                  3365      3365
#
#                                   REPORTING_AREA  SHOOTING  OCCURRED_ON_DATE  \
# OFFENSE_CODE_GROUP
# Aggravated Assault                          2947      2947              2947
# Aircraft                                       9         9                 9
# Arson                                         40        40                40
# Assembly or Gathering Violations             343       343               343
# Auto Theft                                  1661      1661              1661
# ...                                          ...       ...               ...
# Towed                                       4177      4177              4177
# Vandalism                                   5837      5837              5837
# Verbal Disputes                             5003      5003              5003
# Violations                                  1712      1712              1712
# Warrant Arrests                             3365      3365              3365
#
#                                   YEAR  MONTH  DAY_OF_WEEK  HOUR  UCR_PART  \
# OFFENSE_CODE_GROUP
# Aggravated Assault                2947   2947         2947  2947      2947
# Aircraft                             9      9            9     9         9
# Arson                               40     40           40    40        40
# Assembly or Gathering Violations   343    343          343   343       343
# Auto Theft                        1661   1661         1661  1661      1661
# ...                                ...    ...          ...   ...       ...
# Towed                             4177   4177         4177  4177      4177
# Vandalism                         5837   5837         5837  5837      5837
# Verbal Disputes                   5003   5003         5003  5003      5003
# Violations                        1712   1712         1712  1712      1712
# Warrant Arrests                   3365   3365         3365  3365      3365
#
#                                   STREET   Lat  Long  Location
# OFFENSE_CODE_GROUP
# Aggravated Assault                  2947  2947  2947      2947
# Aircraft                               9     9     9         9
# Arson                                 40    40    40        40
# Assembly or Gathering Violations     343   343   343       343
# Auto Theft                          1661  1661  1661      1661
# ...                                  ...   ...   ...       ...
# Towed                               4177  4177  4177      4177
# Vandalism                           5837  5837  5837      5837
# Verbal Disputes                     5003  5003  5003      5003
# Violations                          1712  1712  1712      1712
# Warrant Arrests                     3365  3365  3365      3365
#
# [62 rows x 16 columns]

# %%
df['INCIDENT_NUMBER'].astype(str)
# Out:
# 0            I182078893
# 1            I182078893
# 2            I182078872
# 3            I182077958
# 4            I182077958
#               ...
# 110786    I050310906-00
# 110787    I030217815-08
# 110788    I030217815-08
# 110789    I010370257-00
# 110790        142052550
# Name: INCIDENT_NUMBER, Length: 110791, dtype: object

# %%
df['OFFENSE_CODE_GROUP'].astype(str)
# Out:
# 0         Aggravated Assault
# 1                 Ballistics
# 2         Aggravated Assault
# 3         Aggravated Assault
# 4                 Ballistics
#                  ...
# 110786       Warrant Arrests
# 110787              Homicide
# 110788       Warrant Arrests
# 110789       Warrant Arrests
# 110790       Warrant Arrests
# Name: OFFENSE_CODE_GROUP, Length: 110791, dtype: object

# %%
df['OFFENSE_DESCRIPTION'].astype(str)
# Out:
# 0              ASSAULT - AGGRAVATED - BATTERY
# 1                   BALLISTICS EVIDENCE/FOUND
# 2              ASSAULT - AGGRAVATED - BATTERY
# 3              ASSAULT - AGGRAVATED - BATTERY
# 4                   BALLISTICS EVIDENCE/FOUND
#                          ...
# 110786                         WARRANT ARREST
# 110787    MURDER, NON-NEGLIGIENT MANSLAUGHTER
# 110788                         WARRANT ARREST
# 110789                         WARRANT ARREST
# 110790                         WARRANT ARREST
# Name: OFFENSE_DESCRIPTION, Length: 110791, dtype: object

# %%
df['DISTRICT'].astype(str)
# Out:
# 0         C11
# 1         C11
# 2          B2
# 3          B3
# 4          B3
#          ...
# 110786     D4
# 110787    E18
# 110788    E18
# 110789    E13
# 110790     D4
# Name: DISTRICT, Length: 110791, dtype: object

# %%
df[ 'REPORTING_AREA'] .astype(str)
# Out:
# 0         416
# 1         416
# 2         330
# 3         428
# 4         428
#          ...
# 110786    285
# 110787    520
# 110788    520
# 110789    569
# 110790    903
# Name: REPORTING_AREA, Length: 110791, dtype: object

# %%
df['OCCURRED_ON_DATE'].astype(str)
# Out:
# 0         2018-09-29 21:12:00
# 1         2018-09-29 21:12:00
# 2         2018-09-29 19:21:00
# 3         2018-09-26 20:20:00
# 4         2018-09-26 20:20:00
#                  ...
# 110786    2016-06-05 17:25:00
# 110787    2015-07-09 13:38:00
# 110788    2015-07-09 13:38:00
# 110789    2016-05-31 19:35:00
# 110790    2015-06-22 00:12:00
# Name: OCCURRED_ON_DATE, Length: 110791, dtype: object

# %%
df['DAY_OF_WEEK'].astype(str)
# Out:
# 0          Saturday
# 1          Saturday
# 2          Saturday
# 3         Wednesday
# 4         Wednesday
#             ...
# 110786       Sunday
# 110787     Thursday
# 110788     Thursday
# 110789      Tuesday
# 110790       Monday
# Name: DAY_OF_WEEK, Length: 110791, dtype: object

# %%
df['STREET'].astype(str)
# Out:
# 0             WASHINGTON ST
# 1             WASHINGTON ST
# 2                 SEAVER ST
# 3                 MORTON ST
# 4                 MORTON ST
#                 ...
# 110786          COVENTRY ST
# 110787             RIVER ST
# 110788             RIVER ST
# 110789    NEW WASHINGTON ST
# 110790        WASHINGTON ST
# Name: STREET, Length: 110791, dtype: object

# %%
 df['UCR_PART'].astype(str)
# Out:
# 0           Part One
# 1           Part Two
# 2           Part One
# 3           Part One
# 4           Part Two
#              ...
# 110786    Part Three
# 110787      Part One
# 110788    Part Three
# 110789    Part Three
# 110790    Part Three
# Name: UCR_PART, Length: 110791, dtype: object

# %%
df['Long'].astype(str)
# Out:
# 0         -71.07111848
# 1         -71.07111848
# 2         -71.08295366
# 3         -71.08938232
# 4         -71.08938232
#               ...
# 110786    -71.08574813
# 110787    -71.12317207
# 110788    -71.12317207
# 110789    -71.11156487
# 110790    -71.08029038
# Name: Long, Length: 110791, dtype: object

# %%
 df['Location'].astype(str)
# Out:
# 0         (42.28164735, -71.07111848)
# 1         (42.28164735, -71.07111848)
# 2         (42.30455372, -71.08295366)
# 3         (42.28374593, -71.08938232)
# 4         (42.28374593, -71.08938232)
#                      ...
# 110786    (42.33695098, -71.08574813)
# 110787    (42.25592648, -71.12317207)
# 110788    (42.25592648, -71.12317207)
# 110789    (42.30233307, -71.11156487)
# 110790    (42.33383935, -71.08029038)
# Name: Location, Length: 110791, dtype: object

# %%
df['Lat'].astype(str)
# Out:
# 0         42.28164735
# 1         42.28164735
# 2         42.30455372
# 3         42.28374593
# 4         42.28374593
#              ...
# 110786    42.33695098
# 110787    42.25592648
# 110788    42.25592648
# 110789    42.30233307
# 110790    42.33383935
# Name: Lat, Length: 110791, dtype: object

# %%
df['OFFENSE_CODE'].astype(str)
# Out:
# 0          413
# 1         2662
# 2          413
# 3          413
# 4         2662
#           ...
# 110786    3125
# 110787     111
# 110788    3125
# 110789    3125
# 110790    3125
# Name: OFFENSE_CODE, Length: 110791, dtype: object

# %%
df.dtypes
# Out:
# INCIDENT_NUMBER                object
# OFFENSE_CODE                    int64
# OFFENSE_CODE_GROUP             object
# OFFENSE_DESCRIPTION            object
# DISTRICT                       object
# REPORTING_AREA                 object
# SHOOTING                       object
# OCCURRED_ON_DATE       datetime64[ns]
# YEAR                            int64
# MONTH                           int64
# DAY_OF_WEEK                    object
# HOUR                            int64
# UCR_PART                       object
# STREET                         object
# Lat                            object
# Long                           object
# Location                       object
# dtype: object

# %%
import numpy as np
df['SHOOTING'].replace(np.nan , 'N' , inplace = True , regex=True)
# Out:
# C:\Users\ygrov\AppData\Local\Temp\ipykernel_30408\4041483170.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['SHOOTING'].replace(np.nan , 'N' , inplace = True , regex=True)

# %%
df.dropna(axis=0, how='all',subset=None, inplace=True)

# %%
df.head(10)
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0      I182078893           413  Aggravated Assault
# 1      I182078893          2662          Ballistics
# 2      I182078872           413  Aggravated Assault
# 3      I182077958           413  Aggravated Assault
# 4      I182077958          2662          Ballistics
# 5      I182077113           413  Aggravated Assault
# 6      I182077113          1510  Firearm Violations
# 7      I182077113          3130     Search Warrants
# 8      I182077113          1501  Firearm Violations
# 9      I182076987           413  Aggravated Assault
#
#                              OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 0                 ASSAULT - AGGRAVATED - BATTERY      C11            416
# 1                      BALLISTICS EVIDENCE/FOUND      C11            416
# 2                 ASSAULT - AGGRAVATED - BATTERY       B2            330
# 3                 ASSAULT - AGGRAVATED - BATTERY       B3            428
# 4                      BALLISTICS EVIDENCE/FOUND       B3            428
# 5                 ASSAULT - AGGRAVATED - BATTERY       B2            276
# 6             WEAPON - FIREARM - OTHER VIOLATION       B2            276
# 7                                 SEARCH WARRANT       B2            276
# 8  WEAPON - FIREARM - CARRYING / POSSESSING, ETC       B2            276
# 9                 ASSAULT - AGGRAVATED - BATTERY       D4            156
#
#   SHOOTING    OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 0        Y 2018-09-29 21:12:00  2018      9    Saturday    21    Part One
# 1        Y 2018-09-29 21:12:00  2018      9    Saturday    21    Part Two
# 2        Y 2018-09-29 19:21:00  2018      9    Saturday    19    Part One
# 3        Y 2018-09-26 20:20:00  2018      9   Wednesday    20    Part One
# 4        Y 2018-09-26 20:20:00  2018      9   Wednesday    20    Part Two
# 5        Y 2018-09-24 06:20:00  2018      9      Monday     6    Part One
# 6        Y 2018-09-24 06:20:00  2018      9      Monday     6    Part Two
# 7        Y 2018-09-24 06:20:00  2018      9      Monday     6  Part Three
# 8        Y 2018-09-24 06:20:00  2018      9      Monday     6    Part Two
# 9        Y 2018-09-23 13:53:00  2018      9      Sunday    13    Part One
#
#              STREET          Lat          Long                     Location
# 0     WASHINGTON ST  42.28164735  -71.07111848  (42.28164735, -71.07111848)
# 1     WASHINGTON ST  42.28164735  -71.07111848  (42.28164735, -71.07111848)
# 2         SEAVER ST  42.30455372  -71.08295366  (42.30455372, -71.08295366)
# 3         MORTON ST  42.28374593  -71.08938232  (42.28374593, -71.08938232)
# 4         MORTON ST  42.28374593  -71.08938232  (42.28374593, -71.08938232)
# 5       SHAWMUT AVE  42.33248759  -71.08365801  (42.33248759, -71.08365801)
# 6       SHAWMUT AVE  42.33248759  -71.08365801  (42.33248759, -71.08365801)
# 7       SHAWMUT AVE  42.33248759  -71.08365801  (42.33248759, -71.08365801)
# 8       SHAWMUT AVE  42.33248759  -71.08365801  (42.33248759, -71.08365801)
# 9  W SPRINGFIELD ST  42.33795319   -71.0774931  (42.33795319, -71.07749310)

# %%
df.to_csv("cleaned_dataset.csv", sep=',', encoding = "ISO-8859-1")

# %%
import numpy as np
df['STREET'].replace(np.nan , ' ' , inplace = True , regex=True)
# Out:
# C:\Users\ygrov\AppData\Local\Temp\ipykernel_30408\2537343023.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['STREET'].replace(np.nan , ' ' , inplace = True , regex=True)

# %%
import numpy as np
df['DISTRICT'].replace(np.nan , ' ' , inplace = True , regex=True)
# Out:
# C:\Users\ygrov\AppData\Local\Temp\ipykernel_30408\2686393099.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DISTRICT'].replace(np.nan , ' ' , inplace = True , regex=True)

# %%
import numpy as np
df['Lat'].replace(np.nan , '0.0' , inplace = True , regex=True)
# Out:
# C:\Users\ygrov\AppData\Local\Temp\ipykernel_30408\2083559677.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Lat'].replace(np.nan , '0.0' , inplace = True , regex=True)

# %%
df['Long'].replace(np.nan , '0.0' , inplace = True , regex=True)
# Out:
# C:\Users\ygrov\AppData\Local\Temp\ipykernel_30408\4170388092.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Long'].replace(np.nan , '0.0' , inplace = True , regex=True)

# %%
df['UCR_PART'].replace(np.nan , ' ' , inplace = True , regex=True)
# Out:
# C:\Users\ygrov\AppData\Local\Temp\ipykernel_30408\2222065259.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['UCR_PART'].replace(np.nan , ' ' , inplace = True , regex=True)

# %%
df['SHOOTING'].astype(str)
# Out:
# 0         Y
# 1         Y
# 2         Y
# 3         Y
# 4         Y
#          ..
# 110786    N
# 110787    N
# 110788    N
# 110789    N
# 110790    N
# Name: SHOOTING, Length: 110791, dtype: object

# %%
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0      I182078893           413  Aggravated Assault
# 1      I182078893          2662          Ballistics
# 2      I182078872           413  Aggravated Assault
# 3      I182077958           413  Aggravated Assault
# 4      I182077958          2662          Ballistics
#
#               OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0  ASSAULT - AGGRAVATED - BATTERY      C11            416        Y
# 1       BALLISTICS EVIDENCE/FOUND      C11            416        Y
# 2  ASSAULT - AGGRAVATED - BATTERY       B2            330        Y
# 3  ASSAULT - AGGRAVATED - BATTERY       B3            428        Y
# 4       BALLISTICS EVIDENCE/FOUND       B3            428        Y
#
#      OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  UCR_PART         STREET  \
# 0 2018-09-29 21:12:00  2018      9    Saturday    21  Part One  WASHINGTON ST
# 1 2018-09-29 21:12:00  2018      9    Saturday    21  Part Two  WASHINGTON ST
# 2 2018-09-29 19:21:00  2018      9    Saturday    19  Part One      SEAVER ST
# 3 2018-09-26 20:20:00  2018      9   Wednesday    20  Part One      MORTON ST
# 4 2018-09-26 20:20:00  2018      9   Wednesday    20  Part Two      MORTON ST
#
#            Lat          Long                     Location
# 0  42.28164735  -71.07111848  (42.28164735, -71.07111848)
# 1  42.28164735  -71.07111848  (42.28164735, -71.07111848)
# 2  42.30455372  -71.08295366  (42.30455372, -71.08295366)
# 3  42.28374593  -71.08938232  (42.28374593, -71.08938232)
# 4  42.28374593  -71.08938232  (42.28374593, -71.08938232)

# %% [markdown]
# Verifying whether any column still has any null values.

# %%
df.isnull().values.any()
# Out:
# np.False_

# %%
df.isnull().sum()
# Out:
# INCIDENT_NUMBER        0
# OFFENSE_CODE           0
# OFFENSE_CODE_GROUP     0
# OFFENSE_DESCRIPTION    0
# DISTRICT               0
# REPORTING_AREA         0
# SHOOTING               0
# OCCURRED_ON_DATE       0
# YEAR                   0
# MONTH                  0
# DAY_OF_WEEK            0
# HOUR                   0
# UCR_PART               0
# STREET                 0
# Lat                    0
# Long                   0
# Location               0
# dtype: int64

# %%
df.head(10)
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0      I182078893           413  Aggravated Assault
# 1      I182078893          2662          Ballistics
# 2      I182078872           413  Aggravated Assault
# 3      I182077958           413  Aggravated Assault
# 4      I182077958          2662          Ballistics
# 5      I182077113           413  Aggravated Assault
# 6      I182077113          1510  Firearm Violations
# 7      I182077113          3130     Search Warrants
# 8      I182077113          1501  Firearm Violations
# 9      I182076987           413  Aggravated Assault
#
#                              OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 0                 ASSAULT - AGGRAVATED - BATTERY      C11            416
# 1                      BALLISTICS EVIDENCE/FOUND      C11            416
# 2                 ASSAULT - AGGRAVATED - BATTERY       B2            330
# 3                 ASSAULT - AGGRAVATED - BATTERY       B3            428
# 4                      BALLISTICS EVIDENCE/FOUND       B3            428
# 5                 ASSAULT - AGGRAVATED - BATTERY       B2            276
# 6             WEAPON - FIREARM - OTHER VIOLATION       B2            276
# 7                                 SEARCH WARRANT       B2            276
# 8  WEAPON - FIREARM - CARRYING / POSSESSING, ETC       B2            276
# 9                 ASSAULT - AGGRAVATED - BATTERY       D4            156
#
#   SHOOTING    OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 0        Y 2018-09-29 21:12:00  2018      9    Saturday    21    Part One
# 1        Y 2018-09-29 21:12:00  2018      9    Saturday    21    Part Two
# 2        Y 2018-09-29 19:21:00  2018      9    Saturday    19    Part One
# 3        Y 2018-09-26 20:20:00  2018      9   Wednesday    20    Part One
# 4        Y 2018-09-26 20:20:00  2018      9   Wednesday    20    Part Two
# 5        Y 2018-09-24 06:20:00  2018      9      Monday     6    Part One
# 6        Y 2018-09-24 06:20:00  2018      9      Monday     6    Part Two
# 7        Y 2018-09-24 06:20:00  2018      9      Monday     6  Part Three
# 8        Y 2018-09-24 06:20:00  2018      9      Monday     6    Part Two
# 9        Y 2018-09-23 13:53:00  2018      9      Sunday    13    Part One
#
#              STREET          Lat          Long                     Location
# 0     WASHINGTON ST  42.28164735  -71.07111848  (42.28164735, -71.07111848)
# 1     WASHINGTON ST  42.28164735  -71.07111848  (42.28164735, -71.07111848)
# 2         SEAVER ST  42.30455372  -71.08295366  (42.30455372, -71.08295366)
# 3         MORTON ST  42.28374593  -71.08938232  (42.28374593, -71.08938232)
# 4         MORTON ST  42.28374593  -71.08938232  (42.28374593, -71.08938232)
# 5       SHAWMUT AVE  42.33248759  -71.08365801  (42.33248759, -71.08365801)
# 6       SHAWMUT AVE  42.33248759  -71.08365801  (42.33248759, -71.08365801)
# 7       SHAWMUT AVE  42.33248759  -71.08365801  (42.33248759, -71.08365801)
# 8       SHAWMUT AVE  42.33248759  -71.08365801  (42.33248759, -71.08365801)
# 9  W SPRINGFIELD ST  42.33795319   -71.0774931  (42.33795319, -71.07749310)

# %% [markdown]
# ### Performing EDA on the dataset and plotting graphs

# %%
count_week = df.groupby(df.DAY_OF_WEEK).count()
count_week
# Out:
#              INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# DAY_OF_WEEK
# Friday                 15587         15587               15587
# Monday                 16331         16331               16331
# Saturday               15053         15053               15053
# Sunday                 14732         14732               14732
# Thursday               16520         16520               16520
# Tuesday                15839         15839               15839
# Wednesday              16729         16729               16729
#
#              OFFENSE_DESCRIPTION  DISTRICT  REPORTING_AREA  SHOOTING  \
# DAY_OF_WEEK
# Friday                     15587     15587           15587     15587
# Monday                     16331     16331           16331     16331
# Saturday                   15053     15053           15053     15053
# Sunday                     14732     14732           14732     14732
# Thursday                   16520     16520           16520     16520
# Tuesday                    15839     15839           15839     15839
# Wednesday                  16729     16729           16729     16729
#
#              OCCURRED_ON_DATE   YEAR  MONTH   HOUR  UCR_PART  STREET    Lat  \
# DAY_OF_WEEK
# Friday                  15587  15587  15587  15587     15587   15587  15587
# Monday                  16331  16331  16331  16331     16331   16331  16331
# Saturday                15053  15053  15053  15053     15053   15053  15053
# Sunday                  14732  14732  14732  14732     14732   14732  14732
# Thursday                16520  16520  16520  16520     16520   16520  16520
# Tuesday                 15839  15839  15839  15839     15839   15839  15839
# Wednesday               16729  16729  16729  16729     16729   16729  16729
#
#               Long  Location
# DAY_OF_WEEK
# Friday       15587     15587
# Monday       16331     16331
# Saturday     15053     15053
# Sunday       14732     14732
# Thursday     16520     16520
# Tuesday      15839     15839
# Wednesday    16729     16729

# %%
d1=df.groupby(df.OFFENSE_CODE_GROUP).count()
d1
# Out:
#                                   INCIDENT_NUMBER  OFFENSE_CODE  \
# OFFENSE_CODE_GROUP
# Aggravated Assault                           2947          2947
# Aircraft                                        9             9
# Arson                                          40            40
# Assembly or Gathering Violations              343           343
# Auto Theft                                   1661          1661
# ...                                           ...           ...
# Towed                                        4177          4177
# Vandalism                                    5837          5837
# Verbal Disputes                              5003          5003
# Violations                                   1712          1712
# Warrant Arrests                              3365          3365
#
#                                   OFFENSE_DESCRIPTION  DISTRICT  \
# OFFENSE_CODE_GROUP
# Aggravated Assault                               2947      2947
# Aircraft                                            9         9
# Arson                                              40        40
# Assembly or Gathering Violations                  343       343
# Auto Theft                                       1661      1661
# ...                                               ...       ...
# Towed                                            4177      4177
# Vandalism                                        5837      5837
# Verbal Disputes                                  5003      5003
# Violations                                       1712      1712
# Warrant Arrests                                  3365      3365
#
#                                   REPORTING_AREA  SHOOTING  OCCURRED_ON_DATE  \
# OFFENSE_CODE_GROUP
# Aggravated Assault                          2947      2947              2947
# Aircraft                                       9         9                 9
# Arson                                         40        40                40
# Assembly or Gathering Violations             343       343               343
# Auto Theft                                  1661      1661              1661
# ...                                          ...       ...               ...
# Towed                                       4177      4177              4177
# Vandalism                                   5837      5837              5837
# Verbal Disputes                             5003      5003              5003
# Violations                                  1712      1712              1712
# Warrant Arrests                             3365      3365              3365
#
#                                   YEAR  MONTH  DAY_OF_WEEK  HOUR  UCR_PART  \
# OFFENSE_CODE_GROUP
# Aggravated Assault                2947   2947         2947  2947      2947
# Aircraft                             9      9            9     9         9
# Arson                               40     40           40    40        40
# Assembly or Gathering Violations   343    343          343   343       343
# Auto Theft                        1661   1661         1661  1661      1661
# ...                                ...    ...          ...   ...       ...
# Towed                             4177   4177         4177  4177      4177
# Vandalism                         5837   5837         5837  5837      5837
# Verbal Disputes                   5003   5003         5003  5003      5003
# Violations                        1712   1712         1712  1712      1712
# Warrant Arrests                   3365   3365         3365  3365      3365
#
#                                   STREET   Lat  Long  Location
# OFFENSE_CODE_GROUP
# Aggravated Assault                  2947  2947  2947      2947
# Aircraft                               9     9     9         9
# Arson                                 40    40    40        40
# Assembly or Gathering Violations     343   343   343       343
# Auto Theft                          1661  1661  1661      1661
# ...                                  ...   ...   ...       ...
# Towed                               4177  4177  4177      4177
# Vandalism                           5837  5837  5837      5837
# Verbal Disputes                     5003  5003  5003      5003
# Violations                          1712  1712  1712      1712
# Warrant Arrests                     3365  3365  3365      3365
#
# [62 rows x 16 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(25, 20))
sns.countplot(y="OFFENSE_CODE_GROUP", data=df, palette="Set1",);
# Out:
# C:\Users\ygrov\AppData\Local\Temp\ipykernel_30408\1092339337.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y="OFFENSE_CODE_GROUP", data=df, palette="Set1",);

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 6))
sns.countplot(x="STREET", hue="SHOOTING", data=df)  # Corrected argument specification
plt.xlabel('STREET', fontsize=12)
plt.title('Frequency of Shootings by Street')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.show()

# %%
import seaborn as sns

sns.countplot(x="SHOOTING", hue="DISTRICT", data=df)  # Corrected argument specification
plt.xlabel('SHOOTING', fontsize=12)
plt.title('Shootings by District')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x="DISTRICT", hue="SHOOTING", data=df)  # Corrected argument specification
plt.xlabel('DISTRICT', fontsize=12)
plt.title('Frequency of Shootings by District')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 6))
sns.countplot(x="YEAR", hue="SHOOTING", data=df)  # Corrected argument specification
plt.xlabel('YEAR', fontsize=12)
plt.title('Frequency of Shootings per Year')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_count = df['HOUR'].value_counts()
sns.set(style="darkgrid")
sns.barplot(x=df_count.index, y=df_count.values, alpha=1)  # Corrected argument specification
plt.xlabel('HOUR', fontsize=12)
plt.title('Frequency of Crimes by Hour')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.show()

# %%
# Percentage in year wise
labels = df['YEAR'].astype('category').cat.categories.tolist()
counts = df['YEAR'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels,  autopct='%1.1f%%',shadow=True) 
ax1.axis('equal')
plt.show()

# %%
# District wise count
sns.catplot(y='DISTRICT',
           kind='count',
            height=8, 
            aspect=1.5,
            order=df.DISTRICT.value_counts().index,
           data=df)

# %%
df.to_csv("revised_dataset.csv", sep='\t', encoding = "ISO-8859-1")
